# %% [markdown]
# ### To cross check if notebook is running on GPU backend

# %% [markdown]
# You should get **'/device:GPU:0'** if notebook is connected to GPU otherwise you will get **' '**

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# # Setup for Google Colab with FastAI

# %% [markdown]
# ###Installing Pytorch

# %%
#!pip install http://download.pytorch.org/whl/cu80/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl && pip install torchvision
# !pip install http://download.pytorch.org/whl/cu75/torch-0.3.0.post4-cp36-cp36m-linux_x86_64.whl  && pip install torchvision
# Out:
# ...
#     100% |████████████████████████████████| 397.4MB 64.6MB/s
# ...
#     100% |████████████████████████████████| 51kB 1.7MB/s
# ...
#     100% |████████████████████████████████| 5.9MB 216kB/s
# ...
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# ...

# %% [markdown]
# ###Workaround for an issue with PIL and FASTAI botocore

# %% [markdown]
# Please refer this [link](http://forums.fast.ai/t/attributeerror-module-pil-image-has-no-attribute-register-extensions/10689/3) for information related to this issue and workaround.

# %%
# !pip install Pillow==4.0.0
# !pip install PIL
# !pip install image
# Out:
# ...
#     100% |████████████████████████████████| 5.6MB 233kB/s
# ...
#   Found existing installation: Pillow 5.0.0
#     Uninstalling Pillow-5.0.0:
#       Successfully uninstalled Pillow-5.0.0
# ...
#   Could not find a version that satisfies the requirement PIL (from versions: )
# No matching distribution found for PIL
# ...
#     100% |████████████████████████████████| 7.1MB 193kB/s
# ...

# %%
# !wget --header="Host: pypi.python.org" --header="User-Agent: Mozilla/5.0 (X11; CrOS x86_64 9765.85.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.140 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.8" --header="Cookie: _ga=GA1.2.1190364161.1516857147; _gid=GA1.2.307521259.1518724759" --header="Connection: keep-alive" "https://pypi.python.org/packages/89/c4/6c04c35b151be978239d0f6d49ab8b689a50804bd23f986068f75187a568/botocore-1.8.44.tar.gz#md5=9a82d19904d6ceffe496d224794c10bc" -O "botocore-1.8.44.tar.gz" -c && tar -xvf *.gz
# Out:
# --2018-03-05 04:01:20--  https://pypi.python.org/packages/89/c4/6c04c35b151be978239d0f6d49ab8b689a50804bd23f986068f75187a568/botocore-1.8.44.tar.gz
# Resolving pypi.python.org (pypi.python.org)... 151.101.0.223, 151.101.64.223, 151.101.128.223, ...
# Connecting to pypi.python.org (pypi.python.org)|151.101.0.223|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4198810 (4.0M) [binary/octet-stream]
# Saving to: ‘botocore-1.8.44.tar.gz’
#
# botocore-1.8.44.tar 100%[===================>]   4.00M  9.30MB/s    in 0.4s
#
# 2018-03-05 04:01:21 (9.30 MB/s) - ‘botocore-1.8.44.tar.gz’ saved [4198810/4198810]
#
# botocore-1.8.44/
# botocore-1.8.44/botocore/
# botocore-1.8.44/botocore/stub.py
# botocore-1.8.44/botocore/serialize.py
# botocore-1.8.44/botocore/auth.py
# botocore-1.8.44/botocore/vendored/
# botocore-1.8.44/botocore/vendored/six.py
# botocore-1.8.44/botocore/vendored/requests/
# botocore-1.8.44/botocore/vendored/requests/structures.py
# ...

# %%
# !cd botocore-1.8.44 && python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing botocore.egg-info/PKG-INFO
# writing dependency_links to botocore.egg-info/dependency_links.txt
# writing requirements to botocore.egg-info/requires.txt
# writing top-level names to botocore.egg-info/top_level.txt
# reading manifest file 'botocore.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# no previously-included directories found matching 'docs/build'
# writing manifest file 'botocore.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/botocore
# copying botocore/parsers.py -> build/lib/botocore
# copying botocore/utils.py -> build/lib/botocore
# copying botocore/paginate.py -> build/lib/botocore
# copying botocore/endpoint.py -> build/lib/botocore
# copying botocore/handlers.py -> build/lib/botocore
# copying botocore/compat.py -> build/lib/botocore
# ...

# %% [markdown]
# ###Installing fastai

# %%
# !pip install fastai
# Out:
# ...
#     100% |████████████████████████████████| 430kB 2.0MB/s
# ...
#     100% |████████████████████████████████| 1.2MB 1.1MB/s
# ...
#     100% |████████████████████████████████| 1.3MB 977kB/s
# ...
#     100% |████████████████████████████████| 71kB 7.2MB/s
# ...
#     100% |████████████████████████████████| 256kB 3.4MB/s
# ...
#     100% |████████████████████████████████| 20.8MB 66kB/s
# ...
#     100% |████████████████████████████████| 24.9MB 55kB/s
# ...
#     100% |████████████████████████████████| 3.4MB 398kB/s
# ...
#     100% |████████████████████████████████| 112kB 9.4MB/s
# ...
#     100% |████████████████████████████████| 51kB 11.9MB/s
# ...
#     100% |████████████████████████████████| 61kB 11.0MB/s
# ...
#     100% |████████████████████████████████| 2.2MB 590kB/s
# ...
#     100% |████████████████████████████████| 552kB 2.3MB/s
# ...
#     88% |████████████████████████████▎   | 3.6MB 52.1MB/s eta 0:00:01
#     100% |████████████████████████████████| 4.1MB 339kB/s
# ...
#     100% |████████████████████████████████| 61kB 9.7MB/s
# ...

# %% [markdown]
# ###Installing libSM and CV2

# %% [markdown]
# The import of fastai is will throw an error that this library is missing. So, Installing the same.

# %%
# !apt update && apt install -y libsm6 libxext6
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu artful InRelease
# Get:2 http://security.ubuntu.com/ubuntu artful-security InRelease [78.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful-updates InRelease [78.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful-backports InRelease [72.2 kB]
# Get:5 http://security.ubuntu.com/ubuntu artful-security/universe Sources [12.0 kB]
# Get:6 http://security.ubuntu.com/ubuntu artful-security/main amd64 Packages [173 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful-updates/universe Sources [29.3 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful-updates/universe amd64 Packages [111 kB]
# Get:9 http://security.ubuntu.com/ubuntu artful-security/universe amd64 Packages [55.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 Packages [286 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful-backports/universe amd64 Packages [3,587 B]
# Fetched 899 kB in 1s (824 kB/s)
# Reading package lists... Done
# Building dependency tree
# ...

# %%
# https://opencv.org/
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2

# %% [markdown]
# # Download RossMann Store Sales from Kaggle

# %% [markdown]
# ### Use this download from Fastai..works without changes each time in Colab

# %%
# !rm -rf ./data/rossmann/

# %%
# !mkdir -p data/rossmann && cd data/rossmann && wget http://files.fast.ai/part2/lesson14/rossmann.tgz
# Out:
# --2018-03-08 17:09:04--  http://files.fast.ai/part2/lesson14/rossmann.tgz
# Resolving files.fast.ai (files.fast.ai)... 67.205.15.147
# Connecting to files.fast.ai (files.fast.ai)|67.205.15.147|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7730448 (7.4M) [text/plain]
# Saving to: ‘rossmann.tgz’
#
# rossmann.tgz        100%[===================>]   7.37M  10.9MB/s    in 0.7s
#
# 2018-03-08 17:09:05 (10.9 MB/s) - ‘rossmann.tgz’ saved [7730448/7730448]

# %%
# !ls -l data/rossmann/rossmann.tgz
# Out:
# -rw-r--r-- 1 root root 7730448 Apr 11  2017 data/rossmann/rossmann.tgz

# %%
# !cd data/rossmann/ && tar zxvf rossmann.tgz
# Out:
# googletrend.csv
# sample_submission.csv
# state_names.csv
# store.csv
# store_states.csv
# test.csv
# train.csv
# weather.csv

# %% [markdown]
# ### Download from Kaggle requires change each time so ignore if run above fine

# %%
# !mkdir -p data/rossmann && cd data/rossmann && wget https://storage.googleapis.com/kaggle-competitions-data/kaggle/7431/train_v2.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520718248&Signature=SsNr0bdBMRZGiP2mog9KccCQsc5dXwdp1qVasmnUD%2BF2%2FhbWjqJdSypOpib5H65UEgGs9uxAFDdLoEsmZiJcBn0OXF%2FBeHbz46Pi4mBHY28PS%2F%2Fyo7%2FcDEO9aLjDzx%2BTDmK%2Bu1yKyBpK23HnlGKQbRb38eHU8bC5xYYaDWH6Na7%2FuKHu4x81HgNEIFqmUt8QU%2BNufI%2BoxIHlZ5PIQ1uHM8v6EP3yssRrFoH7xzuE6fkcLx9Z4PhF41avzSsMS10mgrne%2FObEf97iXJ9hdGWuocgZBUgJbTDQchuMhSpJ%2FfIUzHEjK6T%2F%2FjwvYH%2FNCa286f84%2FylYqYicv34oqxX9rg%3D%3D

# %%
# !ls ./data/rossmann
# Out:
# ls: cannot access './data/rossmann': No such file or directory

# %%
# !cd data/rossmann && wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (X11; CrOS x86_64 9765.85.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.140 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.8" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/7592/store.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520338273&Signature=CA3sIHNJWpyFlbwSQPfkWQfUWC9rVQiIELs9knBM6XM0E9NDkWWXmH3sVDwgt4E%2FQ1EsY%2Bff2f2thOkoNDFc%2B%2B5Skr4ACwY99v0uGe5A4FPOjwJBycFtCH2cbb1jgMOcMMk2ajyltTvSo6Jt3ux65gQ7eYNozZbBS9Y6aO91wNvZN1dMiMCAKBQ1J24BR3Mb8Bws2kzssHH%2Bo8jIq5lSQ8XhINH1SEvjNe6byhwsWnyKFxxAPhfmauZn3yEdti8AEmzWAIA8MoTcdIaZXjvrMuvNtUf08n8qJHTbq5w2ASrI7YhwdYrBbIll6LHlUGlCCnrzkanlgbBepn8nrJ%2FuYw%3D%3D" -O "store.csv" -c
# Out:
# --2018-03-05 04:04:52--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/7592/store.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520338273&Signature=CA3sIHNJWpyFlbwSQPfkWQfUWC9rVQiIELs9knBM6XM0E9NDkWWXmH3sVDwgt4E%2FQ1EsY%2Bff2f2thOkoNDFc%2B%2B5Skr4ACwY99v0uGe5A4FPOjwJBycFtCH2cbb1jgMOcMMk2ajyltTvSo6Jt3ux65gQ7eYNozZbBS9Y6aO91wNvZN1dMiMCAKBQ1J24BR3Mb8Bws2kzssHH%2Bo8jIq5lSQ8XhINH1SEvjNe6byhwsWnyKFxxAPhfmauZn3yEdti8AEmzWAIA8MoTcdIaZXjvrMuvNtUf08n8qJHTbq5w2ASrI7YhwdYrBbIll6LHlUGlCCnrzkanlgbBepn8nrJ%2FuYw%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.141.128, 2607:f8b0:400c:c06::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.141.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45010 (44K) [text/csv]
# Saving to: ‘store.csv’
#
# store.csv           100%[===================>]  43.96K  --.-KB/s    in 0.001s
#
# ...

# %%
# !cd data/rossmann/ && wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (X11; CrOS x86_64 9765.85.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.140 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.8" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/7592/test_v2.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520338349&Signature=c3vX7o5JpBIZxHeC27PHwBppt9Hb6LUI1xVp%2FVPIP0Vcyu1L43CvFtmck3OHZL8hvTx7%2BKxze2ZvuKyUXsYNrjL421MsoO4x4aSb1U%2BgbB3D%2BEWUB6GQFKgdowpf0dFxFIE0Gmf%2FW3CE2yhsH11wHdUVMsMyyieQ0EoprgNlhNXocxiam%2F2WunE1RB883%2FaNIzQKxsLlwueFgnP5xuhyanOsh7ziFRDqrwil6cOwcfY2UC%2BECWOlRCm%2F4Lx54OADIA5UviR9ZfVgR6qsRQ5viyRq1jWqJSiwV6sY1%2FRwpqQrj2dnyP%2FgoUwmHpvn3XMzMo71HvP5kFyRQ5%2F7B6sU7A%3D%3D" -O "test_v2.csv" -c
# Out:
# --2018-03-05 04:05:07--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/7592/test_v2.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520338349&Signature=c3vX7o5JpBIZxHeC27PHwBppt9Hb6LUI1xVp%2FVPIP0Vcyu1L43CvFtmck3OHZL8hvTx7%2BKxze2ZvuKyUXsYNrjL421MsoO4x4aSb1U%2BgbB3D%2BEWUB6GQFKgdowpf0dFxFIE0Gmf%2FW3CE2yhsH11wHdUVMsMyyieQ0EoprgNlhNXocxiam%2F2WunE1RB883%2FaNIzQKxsLlwueFgnP5xuhyanOsh7ziFRDqrwil6cOwcfY2UC%2BECWOlRCm%2F4Lx54OADIA5UviR9ZfVgR6qsRQ5viyRq1jWqJSiwV6sY1%2FRwpqQrj2dnyP%2FgoUwmHpvn3XMzMo71HvP5kFyRQ5%2F7B6sU7A%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.141.128, 2607:f8b0:400c:c06::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.141.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1099661 (1.0M) [text/csv]
# Saving to: ‘test_v2.csv’
#
# test_v2.csv         100%[===================>]   1.05M  --.-KB/s    in 0.007s
#
# ...

# %%
# !cd data/rossmann/ && wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (X11; CrOS x86_64 9765.85.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.140 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.8" "https://storage.googleapis.com/kaggle-competitions-data/kaggle/7592/sample_submission.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520338439&Signature=azbgQJCspqwQvcd%2BdEKRLpXzKvCXVR6GecctdM%2BthBpFDIRRCqtMnt%2FpCEUOkZQ9PwKBJkXUuPkVlTVC5sM3hKjcs33j5b3W%2FADpOSb4E21Whinf66XH6RlG5akrMWddlwQhAOubvSLqDSOo5ReAjxo8AO2hf1zl9SIkpKJyQkKQ4g0wkDMnEXyuMgRDIu8T4m221zlryzApdVVoKfwmSZDNkOhi3kABCA9zaxaGGfjAQ2PcAYbbsdkVVsfK8T3rD06ft2lvoeXWQXaR4nKKFl65AHT%2FEEHpo69Ufh39%2FW4c5jN%2FWOahOcdeJVvcx37zpeuE%2BzjWwrrCQZqAmOn39A%3D%3D" -O "sample_submission.csv" -c
# Out:
# --2018-03-05 04:05:08--  https://storage.googleapis.com/kaggle-competitions-data/kaggle/7592/sample_submission.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1520338439&Signature=azbgQJCspqwQvcd%2BdEKRLpXzKvCXVR6GecctdM%2BthBpFDIRRCqtMnt%2FpCEUOkZQ9PwKBJkXUuPkVlTVC5sM3hKjcs33j5b3W%2FADpOSb4E21Whinf66XH6RlG5akrMWddlwQhAOubvSLqDSOo5ReAjxo8AO2hf1zl9SIkpKJyQkKQ4g0wkDMnEXyuMgRDIu8T4m221zlryzApdVVoKfwmSZDNkOhi3kABCA9zaxaGGfjAQ2PcAYbbsdkVVsfK8T3rD06ft2lvoeXWQXaR4nKKFl65AHT%2FEEHpo69Ufh39%2FW4c5jN%2FWOahOcdeJVvcx37zpeuE%2BzjWwrrCQZqAmOn39A%3D%3D
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.141.128, 2607:f8b0:400c:c06::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.141.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 317611 (310K) [text/csv]
# Saving to: ‘sample_submission.csv’
#
# sample_submission.c 100%[===================>] 310.17K  --.-KB/s    in 0.002s
#
# ...

# %% [markdown]
# There is also an external data set provided by all the Kagglers allowed in the competetion

# %%
# !cd data/rossmann && wget --header="Host: files.fast.ai" --header="User-Agent: Mozilla/5.0 (X11; CrOS x86_64 9765.85.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.140 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8" --header="Accept-Language: en-US,en;q=0.8" --header="Cookie: _ga=GA1.2.499670433.1516936359" --header="Connection: keep-alive" "http://files.fast.ai/part2/lesson14/rossmann.tgz" -O "rossmann.tgz" -c && tar xvf rossmann.tgz
# Out:
# --2018-03-05 04:05:11--  http://files.fast.ai/part2/lesson14/rossmann.tgz
# Resolving files.fast.ai (files.fast.ai)... 67.205.15.147
# Connecting to files.fast.ai (files.fast.ai)|67.205.15.147|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7730448 (7.4M) [text/plain]
# Saving to: ‘rossmann.tgz’
#
# rossmann.tgz        100%[===================>]   7.37M  9.34MB/s    in 0.8s
#
# 2018-03-05 04:05:12 (9.34 MB/s) - ‘rossmann.tgz’ saved [7730448/7730448]
#
# googletrend.csv
# sample_submission.csv
# state_names.csv
# store.csv
# store_states.csv
# test.csv
# train.csv
# weather.csv

# %%
# !ls -l data/rossmann
# Out:
# total 51592
# -rw-rw-r-- 1 1001 1001    86605 Jan 11  2017 googletrend.csv
# -rw-r--r-- 1 root root  7730448 Apr 11  2017 rossmann.tgz
# -rw-r--r-- 1 1001 1001   317611 Sep 29  2015 sample_submission.csv
# -rw-rw-r-- 1 1001 1001      265 Jan 11  2017 state_names.csv
# -rw-r--r-- 1 1001 1001    45010 Sep 29  2015 store.csv
# -rw-rw-r-- 1 1001 1001     9051 Jan  6  2017 store_states.csv
# -rw-r--r-- 1 1001 1001  1427425 Sep 29  2015 test.csv
# -rw-r--r-- 1 root root  1099661 Oct 27 05:57 test_v2.csv
# -rw-r--r-- 1 1001 1001 38057952 Sep 29  2015 train.csv
# -rw-r--r-- 1 root root  2504622 Oct 27 05:57 train_v2.csv
# -rw-rw-r-- 1 1001 1001  1518814 Jan 11  2017 weather.csv
